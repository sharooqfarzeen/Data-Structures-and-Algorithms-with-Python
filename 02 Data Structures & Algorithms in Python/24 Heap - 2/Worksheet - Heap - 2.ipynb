# %%
import heapq as hq

arr = [20, 90, 50, 30, 70]
print(*arr)
heapq.heapify(arr)
# Out:
# 20 90 50 30 70

# %%
print(*arr)
# Out:
# 20 30 50 90 70

# %%
hq.heappop(arr)
# Out:
# 20

# %%
print(*arr)
# Out:
# 30 70 50 90

# %%
hq.heappush(arr, 20)
print(*arr)
# Out:
# 20 30 50 90 70
