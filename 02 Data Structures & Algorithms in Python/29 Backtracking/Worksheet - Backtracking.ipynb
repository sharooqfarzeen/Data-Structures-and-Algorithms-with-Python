# %%
n = 5
visited = [[False] * n for i in range(n)]

# %%
visited
# Out:
# [[False, False, False, False, False],
#  [False, False, False, False, False],
#  [False, False, False, False, False],
#  [False, False, False, False, False],
#  [False, False, False, False, False]]

# %%
import math


phi = (1 + math.sqrt(5)) / 2
return round(pow(phi, n) / math.sqrt(5))

# Driver code
if __name__ == '__main__':
    n = int(input("Enter the value of n: "))
    print("The Fibonacci number using Binet's formula is:", binet(n))

# %%
((10**9)+7)
# Out:
# 1000000007

# %%
(0,0) == (0,0)
# Out:
# True

# %%
(0,0) < (1,0)
# Out:
# True

# %%
(0,0) < (1, -1)
# Out:
# True

# %%
(0,0) < (-1, 2)
# Out:
# False

# %%
test = set()

# %%
test.add((1,2))

# %%
test
# Out:
# {(1, 2)}
