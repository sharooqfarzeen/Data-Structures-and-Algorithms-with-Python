# %% [markdown]
# ## Fibonacci Recursive - Using Dynamic Programming

# %%
def fib(n):
  if n == 1 or n == 0:
    return n
  elif memo[n] != -1:
    return memo[n]
  else:
    memo[n] = fib(n-1) + fib(n-2)
    return memo[n]

#main
n = int(input())

#array for memoization
memo = [-1] * n

print("Nth Fibonacci Number is:", fib(n))
# Out:
# 6
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-641d3ce95e41> in <cell line: 16>()
#      14 memo = [-1] * n
#      15
# ---> 16 print("Nth Fibonacci Number is:", fib(n))
#
# <ipython-input-2-641d3ce95e41> in fib(n)
#       2   if n == 1 or n == 0:
#       3     return n
# ----> 4   elif memo[n] != -1:
#       5     return memo[n]
#       6   else:
#
# IndexError: list index out of range
